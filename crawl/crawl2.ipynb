# %%
#title, author, price, publisher
import requests
url = "https://openapi.naver.com/v1/search/book.json"

start = 1
headers = {
"X-Naver-Client-Id" : 'IsKxcSJYr3oY7Kh9bH6x',
"X-Naver-Client-Secret" :'J3NeunAsWw'
}

book_csv_list = []
no = 1

for idx in range(10):
    start_num = start + (idx * 100)
    
    params = {
        "query":"주식",
        "display":100,
        "start" :str(start_num)
    }

    res = requests.get(url, params=params, headers=headers)
    contents = res.json()
    # print(res.url)


for book in contents['items']:
    # print(book['title'], book['author'],book['discount'],book['publisher'])
    book_csv_list.append([no, book['title'], book['author'],book['discount'],book['publisher']])
    no += 1
print(book_csv_list)
# Out:
# [[1, '부자가 되는 과학적 방법', '월레스 D. 와틀스', '25500', '이담북스'], [2, '주린이도 수익 내는 알짜 주식선정 노하우 9가지 (찾았다! 완전 초보도 할 수 있는 주식투자)', '설춘환', '15300', '이레미디어'], [3, '주식 거인들에게 배우는 잃지 않는 투자 원칙 49 (주식 대가들의 ‘원금보전 투자 철학’을 배운다!)', '김명환', '15300', '스마트비즈니스'], [4, '허영만의 3천만원 1: 주식에 빠지다 (왕초보 허영만의 주식투자 도전기)', '허영만', '12510', '가디언'], [5, '주식 차트 실전 비법 (5가지 키워드를 활용한)', '시부야 다카오', '13500', '한국경제신문i'], [6, '두배버는법', '장환철', '20000', '부크크(bookk)'], [7, '오로형 (변호사시험 법원행시 대비)', '오제현', '54000', '헤르메스'], [8, '주식투자의 첫걸음은 기업분석부터 (돈버는 투자를 위한 기업분석 6단계)', '변지희', '20700', '새로운제안'], [9, '10년 후에도 살아남을 주식에 투자하라 (무극선생과 김민희 앵커가 알려주는 주린이를 위한 실전 투자 교과서)', '김민희^이승조', '17550', '새빛'], [10, '2022 원큐패스 미용사 피부 필기 (NCS를 기반으로 직무 중심으로 개편된 2022년 새 출제기준 완벽 반영!)', '이지안^박규리^임상란^김은숙^김지수', '22500', '다락원'], [11, '이상하게 쉬운 주식 (주식 초보라면 반드시 읽어야 할 주식투자서)', '이상우', '17100', '이상미디랩(이상미디어(주))'], [12, '바이오 투자의 정석(큰글자도서) (개미투자자를 위한 바이오-제약산업 입문서)', '박한슬', '29700', '생각의힘'], [13, '올해는 어떤 종목 사지? 2022 증시 뒤흔들 유망주식 30선 (2022 증시 뒤흔들 유망주식 30선)', '정용택^유승우', '0', '이데일리'], [14,
# ...

# %%
# csv 저장
import csv

with open("./data/books.csv", "w", encoding="utf-8", newline='') as f:
    wt =  csv.writer(f)
    wt.writerows(book_csv_list)

# %%
url = "https://openapi.naver.com/v1/search/book.json"

start = 1
headers = {
"X-Naver-Client-Id" : 'IsKxcSJYr3oY7Kh9bH6x',
"X-Naver-Client-Secret" :'J3NeunAsWw'
}

book_list = []

for idx in range(10):
    start_num = start + (idx * 100)
    
    params = {
        "query":"주식",
        "display":100,
        "start" :str(start_num)
    }

    res = requests.get(url, params=params, headers=headers)
    contents = res.json()
    # print(res.url)

for book in contents['items']:

    book = {"title":book['title'], 
            "author": book['author'], 
            "price": book['discount'], 
            "publisher": book['publisher']
              }
    book_list.append(book)


print(book_list)
# Out:
# [{'title': '부자가 되는 과학적 방법', 'author': '월레스 D. 와틀스', 'price': '25500', 'publisher': '이담북스'}, {'title': '주린이도 수익 내는 알짜 주식선정 노하우 9가지 (찾았다! 완전 초보도 할 수 있는 주식투자)', 'author': '설춘환', 'price': '15300', 'publisher': '이레미디어'}, {'title': '주식 거인들에게 배우는 잃지 않는 투자 원칙 49 (주식 대가들의 ‘원금보전 투자 철학’을 배운다!)', 'author': '김명환', 'price': '15300', 'publisher': '스마트비즈니스'}, {'title': '허영만의 3천만원 1: 주식에 빠지다 (왕초보 허영만의 주식투자 도전기)', 'author': '허영만', 'price': '12510', 'publisher': '가디언'}, {'title': '주식 차트 실전 비법 (5가지 키워드를 활용한)', 'author': '시부야 다카오', 'price': '13500', 'publisher': '한국경제신문i'}, {'title': '두배버는법', 'author': '장환철', 'price': '20000', 'publisher': '부크크(bookk)'}, {'title': '오로형 (변호사시험 법원행시 대비)', 'author': '오제현', 'price': '54000', 'publisher': '헤르메스'}, {'title': '주식투자의 첫걸음은 기업분석부터 (돈버는 투자를 위한 기업분석 6단계)', 'author': '변지희', 'price': '20700', 'publisher': '새로운제안'}, {'title': '10년 후에도 살아남을 주식에 투자하라 (무극선생과 김민희 앵커가 알려주는 주린이를 위한 실전 투자 교과서)', 'author': '김민희^이승조', 'price': '17550', 'publisher': '새빛'}, {'title': '2022 원큐패스 미
# ...

# %%
#몽고db 저장
from pymongo import MongoClient

# MongoDB Atlas[NoSQL DB service] 클러스터에 문자열 연결.
client = MongoClient("mongodb+srv://test:zcfNSl0SUiPZHSFf@cluster0.d5qajhv.mongodb.net/")

#컬랙션 가져오기
db = client['test']
books = db.books


books.insert_many(book_list)
# Out:
# InsertManyResult([ObjectId('684ba1ca79d9b6a36290d510'), ObjectId('684ba1ca79d9b6a36290d511'), ObjectId('684ba1ca79d9b6a36290d512'), ObjectId('684ba1ca79d9b6a36290d513'), ObjectId('684ba1ca79d9b6a36290d514'), ObjectId('684ba1ca79d9b6a36290d515'), ObjectId('684ba1ca79d9b6a36290d516'), ObjectId('684ba1ca79d9b6a36290d517'), ObjectId('684ba1ca79d9b6a36290d518'), ObjectId('684ba1ca79d9b6a36290d519'), ObjectId('684ba1ca79d9b6a36290d51a'), ObjectId('684ba1ca79d9b6a36290d51b'), ObjectId('684ba1ca79d9b6a36290d51c'), ObjectId('684ba1ca79d9b6a36290d51d'), ObjectId('684ba1ca79d9b6a36290d51e'), ObjectId('684ba1ca79d9b6a36290d51f'), ObjectId('684ba1ca79d9b6a36290d520'), ObjectId('684ba1ca79d9b6a36290d521'), ObjectId('684ba1ca79d9b6a36290d522'), ObjectId('684ba1ca79d9b6a36290d523'), ObjectId('684ba1ca79d9b6a36290d524'), ObjectId('684ba1ca79d9b6a36290d525'), ObjectId('684ba1ca79d9b6a36290d526'), ObjectId('684ba1ca79d9b6a36290d527'), ObjectId('684ba1ca79d9b6a36290d528'), ObjectId('684ba1ca79d9b6a36290
# ...

# %%
#네이버openAPI + 엑셀 저장
import requests
from openpyxl import Workbook
import re

wb = Workbook()

#첫번째 sheet 가져오기
ws = wb.active

#시트명 변경
ws.title = "네이버"

#제목행 추가
ws.append(["순위", "상품명", "가격", "주소"])

# 셀 너비 조절
ws.column_dimensions["B"].width = 100

url = "https://openapi.naver.com/v1/search/shop.json"

headers = {
"X-Naver-Client-Id" : 'IsKxcSJYr3oY7Kh9bH6x',
"X-Naver-Client-Secret" :'J3NeunAsWw'
}

start = 1
no =1
book_list = []

for idx in range(10):
    start_num = start + (idx * 100)
    
    params = {
        "query":"마우스",
        "display":100,
        "start" :str(start_num)
    }
    
    res = requests.get(url, params=params, headers=headers)
    contents = res.json()
    # print(res.url)

for item in contents['items']:
    
    #title의 b 태그 제거
    title = re.sub("<.*>" , "", item['title'])    
    print(no, title, item['title'], item['lprice'], item['link'])
    

    ws.append([no, title, item['title'],item['lprice'],item['link']])
    no += 1

#엑셀파일 저장
wb.save("./data/naver.xlsx")
wb.close()
# Out:
# 1 글로리어스 MODEL D PRO 유무선 게이밍  플라밍고 글로리어스 MODEL D PRO 유무선 게이밍 <b>마우스</b> 플라밍고 169000 https://search.shopping.naver.com/catalog/53686928630
# 2 3M WP-5500 3M WP-5500 41400 https://search.shopping.naver.com/catalog/18882960051
# 3 스틸시리즈 RIVAL 5 블랙 스틸시리즈 RIVAL 5 블랙 82000 https://search.shopping.naver.com/catalog/53190040529
# 4 청맥전자 FOR LG CM-2200 레드 청맥전자 FOR LG CM-2200 레드 12980 https://search.shopping.naver.com/catalog/53073209146
# 5 HP 280 무선 저소음  블랙 HP 280 무선 저소음 <b>마우스</b> 블랙 21900 https://search.shopping.naver.com/catalog/53956911608
# 6 [해상도지원/절전모드/인체공학] 무소음 무선  블루투스 [해상도지원/절전모드/인체공학] 무소음 무선 <b>마우스</b> 블루투스 11900 https://dqdawade89.co.kr/goods/goods_view.php?goodsNo=1000000087&inflow=naver
# 7 MS 스컬프트 에고노믹 보호 Ergonomic Sculpt 블랙 무선 유선 인체공학 MS 스컬프트 에고노믹 보호 Ergonomic Sculpt 블랙 무선 유선 인체공학 36400 https://smartstore.naver.com/main/products/11827145991
# 8 마이크로소프트 ELG-00010 블랙 마이크로소프트 ELG-00010 블랙 139900 https://search.shopping.naver.com/catalog/53092830686
# ...
